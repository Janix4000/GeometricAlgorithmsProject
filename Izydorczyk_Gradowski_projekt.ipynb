# %%
from plots import PointsCollection as PC, LinesCollection as LC, Plot, Scene
from Triangulation import Triangulation, Visualiser, OVERLAPING_METHOD, SWAPING_METHOD

# %%
# %matplotlib notebook
drawing_plot = Plot()

drawing_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
points = drawing_plot.get_added_points()
points = points[0].points

# %%
visualiser = Visualiser()
triangulation = Triangulation(points, visualiser=visualiser, method=OVERLAPING_METHOD)
triangles = triangulation.triangulate()
plot = visualiser.get_plot()
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
visualiser = Visualiser()
triangulation = Triangulation(points, visualiser=visualiser, method=SWAPING_METHOD)
triangles = triangulation.triangulate()
plot = visualiser.get_plot()
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
points = []
n = 3
for y in range(n):
    for x in range(n):
        points.append((x / (n - 1), y / (n - 1)))

# %%
visualiser = Visualiser()
triangulation = Triangulation(points, visualiser=visualiser, method=SWAPING_METHOD)
triangles = triangulation.triangulate()
plot = visualiser.get_plot()
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
visualiser = Visualiser()
triangulation = Triangulation(points, visualiser=visualiser, method=OVERLAPING_METHOD)
triangles = triangulation.triangulate()
plot = visualiser.get_plot()
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
